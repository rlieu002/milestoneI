# %%
# %run index.py
# Out:
#            DATE  CPIAUCSL
# 847  2017-08-01 -1.262532
# 848  2017-09-01 -1.166296
# 849  2017-10-01 -1.151614
# 850  2017-11-01 -1.101036
# 851  2017-12-01 -1.060989
#            DATE       PCE
# 703  2017-08-01 -1.268441
# 704  2017-09-01 -1.161679
# 705  2017-10-01 -1.136129
# 706  2017-11-01 -1.049326
# 707  2017-12-01 -0.958049
#            DATE   PSAVERT
# 703  2017-08-01 -0.425885
# 704  2017-09-01 -0.480330
# 705  2017-10-01 -0.462182
# 706  2017-11-01 -0.534776
# 707  2017-12-01 -0.607370
#            DATE   REVOLSL
# 595  2017-08-01 -1.047547
# 596  2017-09-01 -0.914464
# 597  2017-10-01 -0.718370
# 598  2017-11-01 -0.520475
# 599  2017-12-01 -0.437550
#            DATE    UNRATE
# 836  2017-09-01 -0.288816
# 837  2017-10-01 -0.331710
# 838  2017-11-01 -0.331710
# 839  2017-12-01 -0.374604
# 840  2018-01-01 -0.417497
#          DATE     INDEX     value
# 0  2017-08-01  CPIAUCSL -1.262532
# 1  2017-09-01  CPIAUCSL -1.166296
# 2  2017-10-01  CPIAUCSL -1.151614
# ...

# %%
chart = line + line_interest + point
chart
# Out:
# alt.LayerChart(...)

# %%
# seasonally adjusted sales by sector 
sales_data = pd.read_csv('./data/SALES.csv')
# 60 months x 13 sectors
start = sales_data['DATE'].size - (60 * 13)

alt.Chart(sales_data[start:]).mark_line().encode(
    x='DATE',
    y='SALES (SEASONAL ADJ)',
    color='SECTOR',
)
# Out:
# alt.Chart(...)

# %%
# residential housing construction started by region (United States, South, West, Midwest, Northeast)
housing_data = pd.read_csv('./data/RESCONST.csv')
# 60 months x 5 regions
start = housing_data['DATE'].size - (60 * 5)

alt.Chart(housing_data[start:]).mark_line().encode(
    x='DATE',
    y='HOUSING STARTS',
    color='REGION',
)
# Out:
# alt.Chart(...)

# %%
# residential / nonresidential construction spend
construction_data = pd.read_csv('./data/CONSTRUCTION.csv')
# 60 months x 3 types
start = construction_data['DATE'].size - (60 * 3)

alt.Chart(construction_data[start:]).mark_line().encode(
    x='DATE',
    y='CONSTRUCTION SPEND',
    color='TYPE',
)
# Out:
# alt.Chart(...)

# %%
# single family homes for sale / sold by region (United States, South, West, Midwest, Northeast)
home_sales_data = pd.read_csv('./data/HOMESALES.csv')

# filter TYPE on SOLD
homes_sold_df = home_sales_data[home_sales_data['TYPE'] == 'SOLD']
# 60 months x 5 regions
start = homes_sold_df['DATE'].size - (60 * 5)

alt.Chart(homes_sold_df[start:]).mark_line().encode(
    x='DATE',
    y='COUNT',
    color='REGION',
)
# Out:
# alt.Chart(...)

# %%
# filter TYPE on FORSALE
homes_for_sale_df = home_sales_data[home_sales_data['TYPE'] == 'FORSALE']
# 60 months x 5 regions
start = homes_for_sale_df['DATE'].size - (60 * 5)

alt.Chart(homes_for_sale_df[start:]).mark_line().encode(
    x='DATE',
    y='COUNT',
    color='REGION',
)
# Out:
# alt.Chart(...)

# %%
# filter REGION on United States
home_sales_df = home_sales_data[home_sales_data['REGION'] == 'United States']
# 60 months x 2 types
start = home_sales_df['DATE'].size - (60 * 2)

alt.Chart(home_sales_df[start:]).mark_line().encode(
    x='DATE',
    y='COUNT',
    color='TYPE',
)
# Out:
# alt.Chart(...)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d4e15c74-6173-42e1-9532-632717f41fb2' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
